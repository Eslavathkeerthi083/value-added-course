# %%
# import libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image
import seaborn as sns

sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(10,6)})

# %%
# Uniform Distribution
from scipy.stats import uniform

number = 10000
start = 20
width = 25

uniform_data = uniform.rvs(size=number, loc=start, scale=width)
axis = sns.distplot(uniform_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth": 15})
axis.set(xlabel='Uniform Distribution ', ylabel='Frequency')
# Out:
# /tmp/ipython-input-3282965095.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(uniform_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth": 15})
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %%
# Normal distribution
from scipy.stats import norm

normal_data = norm.rvs(size=90000,loc=20,scale=30)
axis = sns.distplot(normal_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth": 15,'alpha':0.568})
axis.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-1042334255.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(normal_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth": 15,'alpha':0.568})
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Gamma distribution
from scipy.stats import gamma

gamma_data = gamma.rvs(a=5, size=10000)
axis = sns.distplot(gamma_data, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 15})
axis.set(xlabel='Example of Gamma Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-3834793733.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(gamma_data, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 15})
# [Text(0.5, 0, 'Example of Gamma Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Exponential distribution
from scipy.stats import expon

expon_data = expon.rvs(scale=1,loc=0,size=1000)
axis = sns.distplot(expon_data, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 15})
axis.set(xlabel='Exponential Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-4208460262.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(expon_data, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 15})
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Poisson Distribution
from scipy.stats import poisson

poisson_data = poisson.rvs(mu=2, size=10000)
axis = sns.distplot(poisson_data, bins=30, kde=False, color='red', hist_kws={"linewidth": 15})
axis.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-3866593985.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(poisson_data, bins=30, kde=False, color='red', hist_kws={"linewidth": 15})
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %%
from scipy.stats import binom

binomial_data = binom.rvs(n=10, p=0.8,size=10000)

axis = sns.distplot(binomial_data, kde=False, color='red', hist_kws={"linewidth": 15})
axis.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# /tmp/ipython-input-2717552648.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(binomial_data, kde=False, color='red', hist_kws={"linewidth": 15})
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# loading data set as Pandas dataframe
df = pd.read_csv("https://raw.githubusercontent.com/PacktPublishing/hands-on-exploratory-data-analysis-with-python/master/Chapter%205/data.csv")
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
# Find out the number of values which are not numeric
df['price'].str.isnumeric().value_counts()

# List out the values which are not numeric
df['price'].loc[df['price'].str.isnumeric() == False]

#Setting the missing value to mean of price and convert the datatype to integer
price = df['price'].loc[df['price'] != '?']
pmean = price.astype(str).astype(int).mean()
df['price'] = df['price'].replace('?',pmean).astype(int)
df['price'].head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int64

# %%
# Cleaning the horsepower losses field
df['horsepower'].str.isnumeric().value_counts()
horsepower = df['horsepower'].loc[df['horsepower'] != '?']
hpmean = horsepower.astype(str).astype(int).mean()
df['horsepower'] = df['horsepower'].replace('?',hpmean).astype(int)
df['horsepower'].head()
# Out:
# 0    111
# 1    111
# 2    154
# 3    102
# 4    115
# Name: horsepower, dtype: int64

# %%
# Cleaning the Normalized losses field
df[df['normalized-losses']=='?'].count()
nl=df['normalized-losses'].loc[df['normalized-losses'] !='?'].count()
nmean=nl.astype(str).astype(int).mean()
df['normalized-losses'] = df['normalized-losses'].replace('?',nmean).astype(int)
df['normalized-losses'].head()
# Out:
# 0    164
# 1    164
# 2    164
# 3    164
# 4    164
# Name: normalized-losses, dtype: int64

# %%
# cleaning the bore
# Find out the number of invalid value
df['bore'].loc[df['bore'] == '?']
# Replace the non-numeric value to null and convert the datatype
df['bore'] = pd.to_numeric(df['bore'],errors='coerce')
df.bore.head()
# Out:
# 0    3.47
# 1    3.47
# 2    2.68
# 3    3.19
# 4    3.19
# Name: bore, dtype: float64

# %%
# Cleaning the column stoke
df['stroke'] = pd.to_numeric(df['stroke'],errors='coerce')
df['stroke'].head()
# Out:
# 0    2.68
# 1    2.68
# 2    3.47
# 3    3.40
# 4    3.40
# Name: stroke, dtype: float64

# %%
# Cleaning the column peak-rpm
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'],errors='coerce')
df['peak-rpm'].head()
# Out:
# 0    5000.0
# 1    5000.0
# 2    5000.0
# 3    5500.0
# 4    5500.0
# Name: peak-rpm, dtype: float64

# %%
# Cleaning the Column num-of-doors data
# remove the records which are having the value '?'
df['num-of-doors'].loc[df['num-of-doors'] == '?']
df= df[df['num-of-doors'] != '?']
df['num-of-doors'].loc[df['num-of-doors'] == '?']
# Out:
# Series([], Name: num-of-doors, dtype: object)

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base     length       width  \
# count  203.000000         203.000000  203.000000  203.00000  203.000000
# mean     0.837438         130.147783   98.781281  174.11330   65.915271
# std      1.250021          35.956490    6.040994   12.33909    2.150274
# min     -2.000000          65.000000   86.600000  141.10000   60.300000
# 25%      0.000000         101.000000   94.500000  166.55000   64.100000
# 50%      1.000000         128.000000   97.000000  173.20000   65.500000
# 75%      2.000000         164.000000  102.400000  183.30000   66.900000
# max      3.000000         256.000000  120.900000  208.10000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  203.000000   203.000000   203.000000  199.000000  199.000000
# mean    53.731527  2557.916256   127.073892    3.330955    3.254070
# std      2.442526   522.557049    41.797123    0.274054    0.318023
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2145.000000    97.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2943.500000   143.000000    3.590000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         203.000000  203.000000   201.000000  203.000000   203.000000
# mean           10.093202  104.463054  5125.870647   25.172414    30.699507
# std             3.888216   39.612384   479.820136    6.529812     6.874645
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5200.000000   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  288.000000  6600.000000   49.000000    54.000000
#
#               price
# count    203.000000
# mean   13241.911330
# std     7898.957924
# min     5118.000000
# 25%     7781.500000
# 50%    10595.000000
# 75%    16500.000000
# max    45400.000000

# %% [markdown]
# Let's start by computing Measure of central tendency

# %%
# get column height from df
height =df["height"]
print(height)
# Out:
# 0      48.8
# 1      48.8
# 2      52.4
# 3      54.3
# 4      54.3
#        ...
# 200    55.5
# 201    55.5
# 202    55.5
# 203    55.5
# 204    55.5
# Name: height, Length: 203, dtype: float64

# %%
#calculate mean, median and mode of dat set height
mean = height.mean()
median =height.median()
mode = height.mode()
print(mean , median, mode)
# Out:
# 53.73152709359606 54.1 0    50.8
# Name: height, dtype: float64

# %% [markdown]
# For categorical variables which has discrite values we can summarize the categorical data is by using the function value_counts().

# %%
import matplotlib.pyplot as plt

df.make.value_counts().nlargest(30).plot(kind='bar', figsize=(14,8))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make of the cars');

# %%
#summarize categories of drive-wheels
drive_wheels_count =df["drive-wheels"].value_counts()
print(drive_wheels_count)
# Out:
# drive-wheels
# fwd    118
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %% [markdown]
# **Measures of Dispersion**

# %%
# Standard deviation for numeric columns only
std_dev = df.select_dtypes(include="number").std()
print(std_dev)

# Standard deviation for height column
std_height = df["height"].std()
print(std_height)
# Out:
# symboling               1.250021
# normalized-losses      35.956490
# wheel-base              6.040994
# length                 12.339090
# width                   2.150274
# height                  2.442526
# curb-weight           522.557049
# engine-size            41.797123
# bore                    0.274054
# stroke                  0.318023
# compression-ratio       3.888216
# horsepower             39.612384
# peak-rpm              479.820136
# city-mpg                6.529812
# highway-mpg             6.874645
# price                7898.957924
# dtype: float64
# 2.442525704031867

# %% [markdown]
# # Measure of variance

# %%
# Variance of only numeric columns in the DataFrame
variance = df.select_dtypes(include="number").var()
print(variance)

# Variance of a specific numeric column
var_height = df["height"].astype(float).var()
print(var_height)
# Out:
# symboling            1.562552e+00
# normalized-losses    1.292869e+03
# wheel-base           3.649361e+01
# length               1.522531e+02
# width                4.623677e+00
# height               5.965932e+00
# curb-weight          2.730659e+05
# engine-size          1.746999e+03
# bore                 7.510565e-02
# stroke               1.011384e-01
# compression-ratio    1.511822e+01
# horsepower           1.569141e+03
# peak-rpm             2.302274e+05
# city-mpg             4.263844e+01
# highway-mpg          4.726074e+01
# price                6.239354e+07
# dtype: float64
# 5.965931814856368

# %%
pd.to_numeric(df["height"], errors="coerce").var()
# Out:
# 5.965931814856368

# %%
df.skew(numeric_only=True)
# Out:
# symboling            0.204275
# normalized-losses    0.209007
# wheel-base           1.041170
# length               0.154086
# width                0.900685
# height               0.064134
# curb-weight          0.668942
# engine-size          1.934993
# bore                 0.013419
# stroke              -0.669515
# compression-ratio    2.682640
# horsepower           1.391224
# peak-rpm             0.073094
# city-mpg             0.673533
# highway-mpg          0.549104
# price                1.812335
# dtype: float64

# %%
df["height"] = pd.to_numeric(df["height"], errors="coerce")
skew_height = df.loc[:, "height"].skew()
print(skew_height)
# Out:
# 0.06413448813322854

# %% [markdown]
# # Kurtosis

# %%
# Kurtosis of numeric data in the DataFrame
kurtosis = df.kurt(numeric_only=True)
print(kurtosis)

# Kurtosis of the specific column
df["height"] = pd.to_numeric(df["height"], errors="coerce")
kurt_height = df.loc[:, "height"].kurt()
print(kurt_height)
# Out:
# symboling           -0.691709
# normalized-losses   -0.471235
# wheel-base           0.986065
# length              -0.075680
# width                0.687375
# height              -0.429298
# curb-weight         -0.069648
# engine-size          5.233661
# bore                -0.830965
# stroke               2.030592
# compression-ratio    5.643878
# horsepower           2.646625
# peak-rpm             0.068155
# city-mpg             0.624470
# highway-mpg          0.479323
# price                3.287412
# dtype: float64
# -0.4292976016374439

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()   # preferred over sns.set()
plt.rcParams['figure.figsize'] = (10, 6)

# %%
# plot the relationship between engine-size and price
plt.scatter(df["engine-size"], df["price"])
plt.title("Scatter Plot: Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()

# %%
# Boxplot to visualize the distribution of price with types of drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)
plt.title("Price Distribution by Drive Wheels")
plt.xlabel("Drive Wheels")
plt.ylabel("Price")
plt.show()

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")
type(df.price[0])
# Out:
# numpy.int64

# %% [markdown]
# # Calculating percentiles

# %%
import numpy as np

# converting height to numeric
height = pd.to_numeric(df["height"], errors="coerce")

# calculating 30th percentile of heights
percentile_30 = np.percentile(height.dropna(), 30)
print(percentile_30)
# Out:
# 52.46

# %% [markdown]
# **Quartiles**
#
# It divides the data set into four equal points.
#
# First quartile = 25th percentile
# Second quartile = 50th percentile (Median)
# Third quartile = 75th percentile
#
# Based on the quartile, there is a another measure called inter-quartile range that also measures the variability in the dataset. It is defined as:
#
# IQR = Q3 - Q1
#
# IQR is not affected by the presence of outliers.

# %%
import numpy as np

# convert price column to numeric
price = pd.to_numeric(df["price"], errors="coerce")

# remove missing values and sort
price = price.dropna().sort_values()

# Quartiles
Q1 = np.percentile(price, 25)
Q2 = np.percentile(price, 50)   # Median
Q3 = np.percentile(price, 75)

# Interquartile Range
IQR = Q3 - Q1

print("Q1:", Q1)
print("Q2 (Median):", Q2)
print("Q3:", Q3)
print("IQR:", IQR)
# Out:
# Q1: 7781.5
# Q2 (Median): 10595.0
# Q3: 16500.0
# IQR: 8718.5

# %%
df["normalized-losses"] = pd.to_numeric(df["normalized-losses"], errors="coerce")
df["normalized-losses"].describe()
# Out:
# count    203.000000
# mean     130.147783
# std       35.956490
# min       65.000000
# 25%      101.000000
# 50%      128.000000
# 75%      164.000000
# max      256.000000
# Name: normalized-losses, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data
scorePhysics = [34,35,35,35,35,35,36,36,37,37,37,37,37,38,38,38,39,39,
                40,40,40,40,40,41,42,42,42,42,42,42,42,42,43,43,43,43,44,44,44,44,44,44,45,
                45,45,45,45,46,46,46,46,46,46,47,47,47,47,47,47,48,48,48,48,48,49,49,49,49,
                49,49,49,49,52,52,52,53,53,53,53,53,53,53,53,54,54,
                54,54,54,54,54,55,55,55,55,55,56,56,56,56,56,56,57,57,57,58,58,59,59,59,59,
                59,59,59,60,60,60,60,60,60,60,61,61,61,61,61,62,62,63,63,63,63,63,64,64,64,
                64,64,64,64,65,65,65,66,66,67,67,68,68,68,68,68,68,68,69,70,71,71,71,72,72,
                72,72,73,73,74,75,76,76,76,76,77,77,78,79,79,80,80,81,84,84,85,85,87,87,88]

scoreLiterature = [49,49,50,51,51,52,52,52,52,53,54,54,55,55,55,55,56,
                   56,56,56,56,57,57,57,58,58,58,59,59,59,60,60,60,60,60,60,60,61,61,61,62,
                   62,62,62,63,63,67,67,68,68,68,68,68,68,69,69,69,69,69,69,
                   70,71,71,71,71,72,72,72,72,73,73,73,73,74,74,74,74,74,75,75,75,76,76,76,
                   77,77,78,78,78,79,79,79,80,80,82,83,85,88]

scoreComputer = [56,57,58,58,58,60,60,61,61,61,61,61,61,62,62,62,62,
                 63,63,63,63,63,64,64,64,64,65,65,66,66,67,67,67,67,67,67,67,68,68,68,69,
                 69,70,70,70,71,71,71,73,73,74,75,75,76,76,77,77,77,78,78,81,82,
                 84,89,90]

# Create DataFrame
df = pd.DataFrame({
    "Score": scorePhysics + scoreLiterature + scoreComputer,
    "Subject": (["Physics"] * len(scorePhysics) +
                ["Literature"] * len(scoreLiterature) +
                ["Computer"] * len(scoreComputer))
})

# Statistical Analysis
print("Mean Scores:")
print(df.groupby("Subject")["Score"].mean(), "\n")

print("Variance:")
print(df.groupby("Subject")["Score"].var(), "\n")

print("Standard Deviation:")
print(df.groupby("Subject")["Score"].std(), "\n")

print("Skewness:")
print(df.groupby("Subject")["Score"].skew(), "\n")

print("Kurtosis:")
print(df.groupby("Subject")["Score"].apply(pd.Series.kurt), "\n")

# Visualization
sns.set_theme()
plt.figure(figsize=(10, 6))
sns.boxplot(x="Subject", y="Score", data=df)
plt.title("Score Distribution by Subject")
plt.xlabel("Subject")
plt.ylabel("Score")
plt.show()
# Out:
# Mean Scores:
# Subject
# Computer      68.046154
# Literature    65.857143
# Physics       56.075676
# Name: Score, dtype: float64
#
# Variance:
# Subject
# Computer       57.732212
# Literature     91.340206
# Physics       174.483373
# Name: Score, dtype: float64
#
# Standard Deviation:
# Subject
# Computer       7.598172
# Literature     9.557207
# Physics       13.209215
# Name: Score, dtype: float64
#
# Skewness:
# Subject
# Computer      0.879863
# Literature    0.077439
# Physics       0.391205
# Name: Score, dtype: float64
#
# Kurtosis:
# Subject
# Computer      0.508752
# Literature   -1.023482
# Physics      -0.594686
# Name: Score, dtype: float64

# %%
 import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.boxplot(scoreComputer, showmeans=True, whis=99)
plt.title("Boxplot of Computer Scores")
plt.ylabel("Scores")
plt.show()

# %%
import matplotlib.pyplot as plt

scores = [scorePhysics, scoreLiterature, scoreComputer]

box = plt.boxplot(scores, showmeans=True, whis=99)

# Color for Physics
plt.setp(box['boxes'][0], color='blue')
plt.setp(box['caps'][0], color='blue')
plt.setp(box['caps'][1], color='blue')
plt.setp(box['whiskers'][0], color='blue')
plt.setp(box['whiskers'][1], color='blue')
plt.setp(box['medians'][0], color='blue')
plt.setp(box['means'][0], marker='o', markerfacecolor='blue', markeredgecolor='blue')

# Color for Literature
plt.setp(box['boxes'][1], color='red')
plt.setp(box['caps'][2], color='red')
plt.setp(box['caps'][3], color='red')
plt.setp(box['whiskers'][2], color='red')
plt.setp(box['whiskers'][3], color='red')
plt.setp(box['medians'][1], color='red')
plt.setp(box['means'][1], marker='o', markerfacecolor='red', markeredgecolor='red')

# Color for Computer
plt.setp(box['boxes'][2], color='green')
plt.setp(box['caps'][4], color='green')
plt.setp(box['caps'][5], color='green')
plt.setp(box['whiskers'][4], color='green')
plt.setp(box['whiskers'][5], color='green')
plt.setp(box['medians'][2], color='green')
plt.setp(box['means'][2], marker='o', markerfacecolor='green', markeredgecolor='green')

plt.ylim([20, 95])
plt.grid(True, axis='y')
plt.title('Distribution of the scores in three subjects', fontsize=18)
plt.ylabel('Total score in that subject')
plt.xticks([1, 2, 3], ['Physics', 'Literature', 'Computer'])

plt.show()
